# %%
#Type String ( berupa teks/ kalimat )
print('Halo')
# Out:
# Halo

# %%
print('halo nama saya pipaww')
# Out:
# halo nama saya pipaww

# %%
#Type Numerik dibagi menjadi :
# 1. Integer(int) / Bil.Bulat. Contoh: 1; 25; 60
# 2. Float(desimal). Contoh: 3.14; 2.34
# 3. Complex Number (Bil.Kompleks). Contoh: 3 + 2j

# %%
print('umur saya') #pake petik bila kalimat/teks
print (19) #tidak pakai petik bila angka
# Out:
# umur saya
# 19

# %%
#Type Boolean, dibagi menjadi :
# 1. True (benar) / false (salah)
# 2. Logic : AND, OR, NOT
# 3. Ekspresi Logic : >; <; >=; <=

# %%
print('TAKUMI')

#Mengambil sub-string
# Step 1: Membuat Variable / Teks
s= 'TAKUMI'

# TAKUMI terdiri dari 6 huruf, namun dalam python, when dibaca dari kiri ke kanan dihitung dari (0-huruf terakhir)
# Namun saat dibaca dari kaanan ke kiri dihitung dari(-1 sampai huruf terakhir)
#Menampilkan karakter pertama 
print(s[0])
#Menampilkan karakter kedua, dst
print(s[1])
# Out:
# TAKUMI
# T
# A

# %%
# Penggunaan " Len () " untuk menampilkan jumlah huruf
#saat dalam kondisi tanpa spasi
s= 'TAKUMI'
len(s)
# Out:
# 6

# %%
#saat dalam kondisi dengan spasi
s= 'TA KU MI'
len(s)
# Out:
# 8
