# %%
data = [1,4,5,6]
#saat "string" digunakan pembedanya adalah "koma(,)" Untuk satu kurung
print("ini adalah indeks ke-3" , data [2]) 
#manual prog print(nama[angkaindeks])
print(data[0])
print(data[1])
print(data[2])
print(data[3])
# Out:
# ini adalah indeks ke-3 5
# 1
# 4
# 5
# 6

# %%
#menggunakan looping (loop) untuk integer 
#dalam loop penggunaaan "for" untuk variabel dan integer
#simpelnya program lebih singkat dan hasil yang sama dari manual prog
# for i in data:
#     print(i)

# %%
# print("lihat menu:\n1.view\n2.exit\n")
# pertanyaan = int(input("masukan pilihan anda"))
#  if pertanyaan == 1
# Out:
#   Cell In[27], line 3
#     if pertanyaan == 1
#     ^
# IndentationError: unexpected indent

# %%
data = [20,6,87,54,73]
print("data :")
for i in data:
    print(i);

    nomor_ubah = int(input("Masukkan urutan yang mau diubah"))
    VALUE_ubah = int(input("Masukkan urutan yang mau diubah"))

    data[nomor_ubah] = VALUE_ubah

    print("data setelah diubah :")
        for i in data:
            print (i)
# Out:
#   Cell In[30], line 12
#     for a in data:
#     ^
# IndentationError: unexpected indent
